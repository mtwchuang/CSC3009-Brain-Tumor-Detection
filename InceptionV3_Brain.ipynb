# %%
import os
import cv2
import glob
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.layers import Dense
from keras.models import Sequential
from keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from keras.layers import Convolution2D,Dense,MaxPool2D,Activation,Dropout,Flatten
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def get_files(directory):
  if not os.path.exists(directory):
    return 0
  count=0
  # crawls inside folders
  for current_path,dirs,files in os.walk(directory):
    for dr in dirs:
      count+= len(glob.glob(os.path.join(current_path,dr+"/*")))
  return count
train_dir ="/content/drive/MyDrive/cleaned_output/Training"
test_dir="/content/drive/MyDrive/cleaned_output/Testing"

# %%
 #train file image count
train_samples =get_files(train_dir)
#to get tags
num_classes=len(glob.glob(train_dir+"/*"))
#test file image count
test_samples=get_files(test_dir)
print(num_classes,"Classes")
print(train_samples,"Train images")
print(test_samples,"Test images")
# Out:
# 4 Classes
# 5712 Train images
# 1311 Test images

# %%
train_datagen=ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
     fill_mode='nearest',
    horizontal_flip=True,
     vertical_flip=True)
test_datagen=ImageDataGenerator(rescale=1./255)

# %%
input_shape=(256,256,3)
train_generator =train_datagen.flow_from_directory(train_dir,target_size=(256,256),batch_size=32)
test_generator=test_datagen.flow_from_directory(test_dir,shuffle=True,target_size=(256,256),batch_size=32)
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %%
IMAGE_SIZE = [256, 256]
inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# We don't need to train existing weights
for layer in inception.layers:
    layer.trainable = False

# %%
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

IMAGE_SIZE = [256, 256]

# Load the InceptionV3 model with weights pre-trained on ImageNet
inception = InceptionV3(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# Freeze the existing weights
for layer in inception.layers:
    layer.trainable = False

# Add your own classification head to the model
x = GlobalAveragePooling2D()(inception.output)
x = Dense(256, activation='relu')(x)
output = Dense(4, activation='softmax')(x)

# Create a new model with the InceptionV3 base and your classification head
model = Model(inputs=inception.input, outputs=output)

# Compile the model (add optimizer, loss function, etc. based on your task)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the summary of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_94 (Conv2D)          (None, 127, 127, 32)         864       ['input_2[0][0]']
#
#  batch_normalization_94 (Ba  (None, 127, 127, 32)         96        ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 127, 127, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 125, 125, 32)         9216      ['activation_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 125, 125, 32)         96        ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 125, 125, 32)         0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_96 (Conv2D)          (None, 125, 125, 64)         18432     ['activation_95[0][0]']
#
#  batch_normalization_96 (Ba  (None, 125, 125, 64)         192       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  activation_96 (Activation)  (None, 125, 125, 64)         0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 62, 62, 64)           0         ['activation_96[0][0]']
#  g2D)
#
#  conv2d_97 (Conv2D)          (None, 62, 62, 80)           5120      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_97 (Ba  (None, 62, 62, 80)           240       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_97 (Activation)  (None, 62, 62, 80)           0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 60, 60, 192)          138240    ['activation_97[0][0]']
#
#  batch_normalization_98 (Ba  (None, 60, 60, 192)          576       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_98 (Activation)  (None, 60, 60, 192)          0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 29, 29, 192)          0         ['activation_98[0][0]']
#  g2D)
#
#  conv2d_102 (Conv2D)         (None, 29, 29, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_102 (B  (None, 29, 29, 64)           192       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_100 (Conv2D)         (None, 29, 29, 48)           9216      ['max_pooling2d_5[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_102[0][0]']
#
#  batch_normalization_100 (B  (None, 29, 29, 48)           144       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  batch_normalization_103 (B  (None, 29, 29, 96)           288       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_100[0][0
#  )                                                                  ]']
#
#  activation_103 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  average_pooling2d_9 (Avera  (None, 29, 29, 192)          0         ['max_pooling2d_5[0][0]']
#  gePooling2D)
#
#  conv2d_99 (Conv2D)          (None, 29, 29, 64)           12288     ['max_pooling2d_5[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 29, 29, 64)           76800     ['activation_100[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 29, 29, 96)           82944     ['activation_103[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 29, 29, 32)           6144      ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (Ba  (None, 29, 29, 64)           192       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 29, 29, 64)           192       ['conv2d_101[0][0]']
#  atchNormalization)
#
#  batch_normalization_104 (B  (None, 29, 29, 96)           288       ['conv2d_104[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 29, 29, 32)           96        ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 29, 29, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  activation_101 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_101[0][0
#  )                                                                  ]']
#
#  activation_104 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  activation_105 (Activation  (None, 29, 29, 32)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 29, 29, 256)          0         ['activation_99[0][0]',
#                                                                      'activation_101[0][0]',
#                                                                      'activation_104[0][0]',
#                                                                      'activation_105[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 29, 29, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_109 (B  (None, 29, 29, 64)           192       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  conv2d_107 (Conv2D)         (None, 29, 29, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_109[0][0]']
#
#  batch_normalization_107 (B  (None, 29, 29, 48)           144       ['conv2d_107[0][0]']
#  atchNormalization)
#
#  batch_normalization_110 (B  (None, 29, 29, 96)           288       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  activation_110 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  average_pooling2d_10 (Aver  (None, 29, 29, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_106 (Conv2D)         (None, 29, 29, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 29, 29, 64)           76800     ['activation_107[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 29, 29, 96)           82944     ['activation_110[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 29, 29, 64)           16384     ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (B  (None, 29, 29, 64)           192       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 29, 29, 64)           192       ['conv2d_108[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 29, 29, 96)           288       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  batch_normalization_112 (B  (None, 29, 29, 64)           192       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  activation_108 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  activation_111 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  activation_112 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_112[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 29, 29, 288)          0         ['activation_106[0][0]',
#                                                                      'activation_108[0][0]',
#                                                                      'activation_111[0][0]',
#                                                                      'activation_112[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 29, 29, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_116 (B  (None, 29, 29, 64)           192       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  activation_116 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_116[0][0
#  )                                                                  ]']
#
#  conv2d_114 (Conv2D)         (None, 29, 29, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_116[0][0]']
#
#  batch_normalization_114 (B  (None, 29, 29, 48)           144       ['conv2d_114[0][0]']
#  atchNormalization)
#
#  batch_normalization_117 (B  (None, 29, 29, 96)           288       ['conv2d_117[0][0]']
#  atchNormalization)
#
#  activation_114 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_114[0][0
#  )                                                                  ]']
#
#  activation_117 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_117[0][0
#  )                                                                  ]']
#
#  average_pooling2d_11 (Aver  (None, 29, 29, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_113 (Conv2D)         (None, 29, 29, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 29, 29, 64)           76800     ['activation_114[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 29, 29, 96)           82944     ['activation_117[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 29, 29, 64)           18432     ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (B  (None, 29, 29, 64)           192       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  batch_normalization_115 (B  (None, 29, 29, 64)           192       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 29, 29, 96)           288       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 29, 29, 64)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  activation_113 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_113[0][0
#  )                                                                  ]']
#
#  activation_115 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_115[0][0
#  )                                                                  ]']
#
#  activation_118 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_118[0][0
#  )                                                                  ]']
#
#  activation_119 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_119[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 29, 29, 288)          0         ['activation_113[0][0]',
#                                                                      'activation_115[0][0]',
#                                                                      'activation_118[0][0]',
#                                                                      'activation_119[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 29, 29, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_121 (B  (None, 29, 29, 64)           192       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  activation_121 (Activation  (None, 29, 29, 64)           0         ['batch_normalization_121[0][0
#  )                                                                  ]']
#
#  conv2d_122 (Conv2D)         (None, 29, 29, 96)           55296     ['activation_121[0][0]']
#
#  batch_normalization_122 (B  (None, 29, 29, 96)           288       ['conv2d_122[0][0]']
#  atchNormalization)
#
#  activation_122 (Activation  (None, 29, 29, 96)           0         ['batch_normalization_122[0][0
#  )                                                                  ]']
#
#  conv2d_120 (Conv2D)         (None, 14, 14, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 14, 14, 96)           82944     ['activation_122[0][0]']
#
#  batch_normalization_120 (B  (None, 14, 14, 384)          1152      ['conv2d_120[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 14, 14, 96)           288       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  activation_120 (Activation  (None, 14, 14, 384)          0         ['batch_normalization_120[0][0
#  )                                                                  ]']
#
#  activation_123 (Activation  (None, 14, 14, 96)           0         ['batch_normalization_123[0][0
#  )                                                                  ]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 14, 14, 768)          0         ['activation_120[0][0]',
#                                                                      'activation_123[0][0]',
#                                                                      'max_pooling2d_6[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 14, 14, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_128 (B  (None, 14, 14, 128)          384       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  activation_128 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_128[0][0
#  )                                                                  ]']
#
#  conv2d_129 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_128[0][0]']
#
#  batch_normalization_129 (B  (None, 14, 14, 128)          384       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  activation_129 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_129[0][0
#  )                                                                  ]']
#
#  conv2d_125 (Conv2D)         (None, 14, 14, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_129[0][0]']
#
#  batch_normalization_125 (B  (None, 14, 14, 128)          384       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  batch_normalization_130 (B  (None, 14, 14, 128)          384       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  activation_125 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_125[0][0
#  )                                                                  ]']
#
#  activation_130 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_130[0][0
#  )                                                                  ]']
#
#  conv2d_126 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_125[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 14, 14, 128)          114688    ['activation_130[0][0]']
#
#  batch_normalization_126 (B  (None, 14, 14, 128)          384       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 14, 14, 128)          384       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  activation_126 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_126[0][0
#  )                                                                  ]']
#
#  activation_131 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_131[0][0
#  )                                                                  ]']
#
#  average_pooling2d_12 (Aver  (None, 14, 14, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_124 (Conv2D)         (None, 14, 14, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 14, 14, 192)          172032    ['activation_126[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 14, 14, 192)          172032    ['activation_131[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 14, 14, 192)          147456    ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (B  (None, 14, 14, 192)          576       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 14, 14, 192)          576       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  batch_normalization_132 (B  (None, 14, 14, 192)          576       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  batch_normalization_133 (B  (None, 14, 14, 192)          576       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_124 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_124[0][0
#  )                                                                  ]']
#
#  activation_127 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_127[0][0
#  )                                                                  ]']
#
#  activation_132 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_132[0][0
#  )                                                                  ]']
#
#  activation_133 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_133[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 14, 14, 768)          0         ['activation_124[0][0]',
#                                                                      'activation_127[0][0]',
#                                                                      'activation_132[0][0]',
#                                                                      'activation_133[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_138 (B  (None, 14, 14, 160)          480       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  activation_138 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_138[0][0
#  )                                                                  ]']
#
#  conv2d_139 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_138[0][0]']
#
#  batch_normalization_139 (B  (None, 14, 14, 160)          480       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  activation_139 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_139[0][0
#  )                                                                  ]']
#
#  conv2d_135 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_139[0][0]']
#
#  batch_normalization_135 (B  (None, 14, 14, 160)          480       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_140 (B  (None, 14, 14, 160)          480       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  activation_135 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_135[0][0
#  )                                                                  ]']
#
#  activation_140 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_140[0][0
#  )                                                                  ]']
#
#  conv2d_136 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_135[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_140[0][0]']
#
#  batch_normalization_136 (B  (None, 14, 14, 160)          480       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  batch_normalization_141 (B  (None, 14, 14, 160)          480       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_136 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_136[0][0
#  )                                                                  ]']
#
#  activation_141 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  average_pooling2d_13 (Aver  (None, 14, 14, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_134 (Conv2D)         (None, 14, 14, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 14, 14, 192)          215040    ['activation_136[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 14, 14, 192)          215040    ['activation_141[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 14, 14, 192)          147456    ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (B  (None, 14, 14, 192)          576       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 14, 14, 192)          576       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_142 (B  (None, 14, 14, 192)          576       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 14, 14, 192)          576       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  activation_134 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_134[0][0
#  )                                                                  ]']
#
#  activation_137 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_137[0][0
#  )                                                                  ]']
#
#  activation_142 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  activation_143 (Activation  (None, 14, 14, 192)          0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 14, 14, 768)          0         ['activation_134[0][0]',
#                                                                      'activation_137[0][0]',
#                                                                      'activation_142[0][0]',
#                                                                      'activation_143[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_148 (B  (None, 14, 14, 160)          480       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  activation_148 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_149 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_148[0][0]']
#
#  batch_normalization_149 (B  (None, 14, 14, 160)          480       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  activation_149 (Activation  (None, 14, 14, 160)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_145 (Conv2D)         (None, 14, 14, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 14, 14, 160)          179200    ['activation_149[0][0]']
#
#  batch_normalization_145 (B  (None, 14, 14, 160)          480       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  batch_normalization_150 (B  (None, 14, 14, 160)          480       ['conv2d_150[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  conv2d_172 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_173 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_171[0][0]']
#
#  conv2d_176 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_175[0][0]']
#
#  conv2d_177 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_175[0][0]']
#
#  average_pooling2d_16 (Aver  (None, 6, 6, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_170 (Conv2D)         (None, 6, 6, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_172 (B  (None, 6, 6, 384)            1152      ['conv2d_172[0][0]']
#  atchNormalization)
#
#  batch_normalization_173 (B  (None, 6, 6, 384)            1152      ['conv2d_173[0][0]']
#  atchNormalization)
#
#  batch_normalization_176 (B  (None, 6, 6, 384)            1152      ['conv2d_176[0][0]']
#  atchNormalization)
#
#  batch_normalization_177 (B  (None, 6, 6, 384)            1152      ['conv2d_177[0][0]']
#  atchNormalization)
#
#  conv2d_178 (Conv2D)         (None, 6, 6, 192)            245760    ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (B  (None, 6, 6, 320)            960       ['conv2d_170[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_172[0][0
#  )                                                                  ]']
#
#  activation_173 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_173[0][0
#  )                                                                  ]']
#
#  activation_176 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_176[0][0
#  )                                                                  ]']
#
#  activation_177 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_177[0][0
#  )                                                                  ]']
#
#  batch_normalization_178 (B  (None, 6, 6, 192)            576       ['conv2d_178[0][0]']
#  atchNormalization)
#
#  activation_170 (Activation  (None, 6, 6, 320)            0         ['batch_normalization_170[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 6, 6, 768)            0         ['activation_172[0][0]',
#                                                                      'activation_173[0][0]']
#
#  concatenate_2 (Concatenate  (None, 6, 6, 768)            0         ['activation_176[0][0]',
#  )                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation  (None, 6, 6, 192)            0         ['batch_normalization_178[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 6, 6, 2048)           0         ['activation_170[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'activation_178[0][0]']
#
#  conv2d_183 (Conv2D)         (None, 6, 6, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_183 (B  (None, 6, 6, 448)            1344      ['conv2d_183[0][0]']
#  atchNormalization)
#
#  activation_183 (Activation  (None, 6, 6, 448)            0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  conv2d_180 (Conv2D)         (None, 6, 6, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_184 (Conv2D)         (None, 6, 6, 384)            1548288   ['activation_183[0][0]']
#
#  batch_normalization_180 (B  (None, 6, 6, 384)            1152      ['conv2d_180[0][0]']
#  atchNormalization)
#
#  batch_normalization_184 (B  (None, 6, 6, 384)            1152      ['conv2d_184[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_180[0][0
#  )                                                                  ]']
#
#  activation_184 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_184[0][0
#  )                                                                  ]']
#
#  conv2d_181 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_182 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_180[0][0]']
#
#  conv2d_185 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_184[0][0]']
#
#  conv2d_186 (Conv2D)         (None, 6, 6, 384)            442368    ['activation_184[0][0]']
#
#  average_pooling2d_17 (Aver  (None, 6, 6, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_179 (Conv2D)         (None, 6, 6, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_181 (B  (None, 6, 6, 384)            1152      ['conv2d_181[0][0]']
#  atchNormalization)
#
#  batch_normalization_182 (B  (None, 6, 6, 384)            1152      ['conv2d_182[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 6, 6, 384)            1152      ['conv2d_185[0][0]']
#  atchNormalization)
#
#  batch_normalization_186 (B  (None, 6, 6, 384)            1152      ['conv2d_186[0][0]']
#  atchNormalization)
#
#  conv2d_187 (Conv2D)         (None, 6, 6, 192)            393216    ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (B  (None, 6, 6, 320)            960       ['conv2d_179[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_181[0][0
#  )                                                                  ]']
#
#  activation_182 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_182[0][0
#  )                                                                  ]']
#
#  activation_185 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_185[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 6, 6, 384)            0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  batch_normalization_187 (B  (None, 6, 6, 192)            576       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_179 (Activation  (None, 6, 6, 320)            0         ['batch_normalization_179[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 6, 6, 768)            0         ['activation_181[0][0]',
#                                                                      'activation_182[0][0]']
#
#  concatenate_3 (Concatenate  (None, 6, 6, 768)            0         ['activation_185[0][0]',
#  )                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation  (None, 6, 6, 192)            0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 6, 6, 2048)           0         ['activation_179[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'activation_187[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['mixed10[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)                  524544    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 4)                    1028      ['dense[0][0]']
#
# ==================================================================================================
# Total params: 22328356 (85.18 MB)
# Trainable params: 525572 (2.00 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
validation_generator = train_datagen.flow_from_directory(
                       test_dir,
                       target_size=(256, 256),
                       batch_size=32)
# Out:
# Found 1311 images belonging to 4 classes.

# %%
history = model.fit(train_generator,
                      steps_per_epoch=None,
                      epochs=30,
                      validation_data=validation_generator,
                      validation_steps=None,
                      verbose=1,
                      callbacks=[ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=0.001)],
                      use_multiprocessing=False,
                      shuffle=True)
# Out:
# Epoch 1/30
# 179/179 [==============================] - 1298s 7s/step - loss: 0.6121 - accuracy: 0.7624 - val_loss: 0.5643 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 2/30
# 179/179 [==============================] - 1274s 7s/step - loss: 0.4052 - accuracy: 0.8512 - val_loss: 0.4957 - val_accuracy: 0.8299 - lr: 0.0010
# Epoch 3/30
# 179/179 [==============================] - 1263s 7s/step - loss: 0.3614 - accuracy: 0.8645 - val_loss: 0.4197 - val_accuracy: 0.8398 - lr: 0.0010
# Epoch 4/30
# 179/179 [==============================] - 1262s 7s/step - loss: 0.3346 - accuracy: 0.8787 - val_loss: 0.4889 - val_accuracy: 0.8345 - lr: 0.0010
# Epoch 5/30
# 179/179 [==============================] - 1264s 7s/step - loss: 0.3373 - accuracy: 0.8746 - val_loss: 0.4687 - val_accuracy: 0.8299 - lr: 0.0010
# Epoch 6/30
# 179/179 [==============================] - 1234s 7s/step - loss: 0.2984 - accuracy: 0.8916 - val_loss: 0.3575 - val_accuracy: 0.8703 - lr: 0.0010
# Epoch 7/30
# 179/179 [==============================] - 1231s 7s/step - loss: 0.2803 - accuracy: 0.8962 - val_loss: 0.3734 - val_accuracy: 0.8574 - lr: 0.0010
# Epoch 8/30
# 179/179 [==============================] - 1229s 7s/step - loss: 0.2743 - accuracy: 0.8983 - val_loss: 0.3680 - val_accuracy: 0.8680 - lr: 0.0010
# Epoch 9/30
# 179/179 [==============================] - 1227s 7s/step - loss: 0.2602 - accuracy: 0.9048 - val_loss: 0.3573 - val_accuracy: 0.8635 - lr: 0.0010
# Epoch 10/30
# 179/179 [==============================] - 1237s 7s/step - loss: 0.2663 - accuracy: 0.9000 - val_loss: 0.3378 - val_accuracy: 0.8764 - lr: 0.0010
# Epoch 11/30
# 179/179 [==============================] - 1264s 7s/step - loss: 0.2279 - accuracy: 0.9160 - val_loss: 0.3515 - val_accuracy: 0.8673 - lr: 0.0010
# Epoch 12/30
# 179/179 [==============================] - 1233s 7s/step - loss: 0.2540 - accuracy: 0.9006 - val_loss: 0.3329 - val_accuracy: 0.8711 - lr: 0.0010
# Epoch 13/30
# 179/179 [==============================] - 1229s 7s/step - loss: 0.2225 - accuracy: 0.9158 - val_loss: 0.3412 - val_accuracy: 0.8780 - lr: 0.0010
# Epoch 14/30
# 179/179 [==============================] - 1268s 7s/step - loss: 0.2317 - accuracy: 0.9156 - val_loss: 0.3244 - val_accuracy: 0.8856 - lr: 0.0010
# Epoch 15/30
# 179/179 [==============================] - 1264s 7s/step - loss: 0.2241 - accuracy: 0.9182 - val_loss: 0.3082 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 16/30
# 179/179 [==============================] - 1261s 7s/step - loss: 0.2217 - accuracy: 0.9188 - val_loss: 0.2911 - val_accuracy: 0.8978 - lr: 0.0010
# Epoch 17/30
# 179/179 [==============================] - 1262s 7s/step - loss: 0.2222 - accuracy: 0.9154 - val_loss: 0.2869 - val_accuracy: 0.8970 - lr: 0.0010
# Epoch 18/30
# 179/179 [==============================] - 1234s 7s/step - loss: 0.2089 - accuracy: 0.9228 - val_loss: 0.2935 - val_accuracy: 0.8902 - lr: 0.0010
# Epoch 19/30
# 179/179 [==============================] - 1263s 7s/step - loss: 0.2052 - accuracy: 0.9226 - val_loss: 0.2955 - val_accuracy: 0.8970 - lr: 0.0010
# Epoch 20/30
# 179/179 [==============================] - 1229s 7s/step - loss: 0.2042 - accuracy: 0.9238 - val_loss: 0.2679 - val_accuracy: 0.9039 - lr: 0.0010
# Epoch 21/30
# 179/179 [==============================] - 1235s 7s/step - loss: 0.1931 - accuracy: 0.9210 - val_loss: 0.3586 - val_accuracy: 0.8696 - lr: 0.0010
# Epoch 22/30
# 179/179 [==============================] - 1237s 7s/step - loss: 0.1885 - accuracy: 0.9303 - val_loss: 0.2613 - val_accuracy: 0.9085 - lr: 0.0010
# Epoch 23/30
# 179/179 [==============================] - 1261s 7s/step - loss: 0.1965 - accuracy: 0.9263 - val_loss: 0.2857 - val_accuracy: 0.8909 - lr: 0.0010
# Epoch 24/30
# 179/179 [==============================] - 1296s 7s/step - loss: 0.1974 - accuracy: 0.9210 - val_loss: 0.2758 - val_accuracy: 0.9016 - lr: 0.0010
# Epoch 25/30
# 179/179 [==============================] - 1265s 7s/step - loss: 0.1774 - accuracy: 0.9335 - val_loss: 0.2855 - val_accuracy: 0.8909 - lr: 0.0010
# Epoch 26/30
# 179/179 [==============================] - 1270s 7s/step - loss: 0.1683 - accuracy: 0.9333 - val_loss: 0.2714 - val_accuracy: 0.9024 - lr: 0.0010
# Epoch 27/30
# 179/179 [==============================] - 1263s 7s/step - loss: 0.1642 - accuracy: 0.9364 - val_loss: 0.2601 - val_accuracy: 0.9047 - lr: 0.0010
# Epoch 28/30
# 179/179 [==============================] - 1228s 7s/step - loss: 0.1647 - accuracy: 0.9345 - val_loss: 0.2569 - val_accuracy: 0.9062 - lr: 0.0010
# Epoch 29/30
# 179/179 [==============================] - 1229s 7s/step - loss: 0.1718 - accuracy: 0.9329 - val_loss: 0.2346 - val_accuracy: 0.9161 - lr: 0.0010
# Epoch 30/30
# 179/179 [==============================] - 1268s 7s/step - loss: 0.1628 - accuracy: 0.9382 - val_loss: 0.3137 - val_accuracy: 0.8932 - lr: 0.0010

# %%
result = model.evaluate(train_generator)
dict(zip(model.metrics_names, result))
# Out:
# 179/179 [==============================] - 998s 6s/step - loss: 0.1870 - accuracy: 0.9245
# {'loss': 0.18695949018001556, 'accuracy': 0.9245448112487793}

# %%
result = model.evaluate(validation_generator)
dict(zip(model.metrics_names, result))
# Out:
# 41/41 [==============================] - 228s 6s/step - loss: 0.3036 - accuracy: 0.8879
# {'loss': 0.30356451869010925, 'accuracy': 0.8878718614578247}

# %%
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `model` is your trained model
# Assuming `validation_generator` contains validation data and labels

# Make predictions on the validation set
predictions = model.predict(validation_generator)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Obtain true labels from the validation generator
true_labels = validation_generator.classes

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix using seaborn
class_names = validation_generator.class_indices.keys()

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 41/41 [==============================] - 232s 6s/step

# %%
from sklearn.metrics import classification_report

# Assuming test_dir is the path to your validation data directory
validation_generator = train_datagen.flow_from_directory(
    test_dir,
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',  # Adjust this based on your problem (binary or multiclass)
    shuffle=False  # Keep the order for evaluation
)

# Assuming model is your trained model
# Assuming history and plt are already defined in your code

# Make predictions on the validation set
predictions = model.predict(validation_generator)

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Obtain true labels from the validation generator
true_labels = validation_generator.classes

# Calculate precision, recall, and F1-score
report = classification_report(true_labels, predicted_labels)
print("Classification Report:")
print(report)
# Out:
# Found 1311 images belonging to 4 classes.
# 41/41 [==============================] - 231s 6s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84       300
#            1       0.71      0.95      0.81       306
#            2       0.98      0.96      0.97       405
#            3       0.96      0.88      0.92       300
#
#     accuracy                           0.89      1311
#    macro avg       0.90      0.88      0.89      1311
# weighted avg       0.91      0.89      0.89      1311
