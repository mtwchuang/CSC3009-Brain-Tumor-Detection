# %% [markdown]
# ## Visual Geometry Group Models (VGG16 & VGG19)
#
# ### Installation and Import Checks

# %%
# %pip install tensorflow==2.10
# %pip install scikit-learn
# %pip install keras_tuner

# %pip install matplotlib
# %matplotlib inline
# %pip install seaborn
# %pip install tabulate
# Out:
# Requirement already satisfied: tensorflow==2.10 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (3.3.0)
# Requirement already satisfied: packaging in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (4.12.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (1.64.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorflow==2.10) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10) (7.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10) (3.19.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.1)
# Requirement already satisfied: six>=1.5 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras_tuner in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from keras_tuner) (2.10.0)
# Requirement already satisfied: packaging in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from keras_tuner) (24.0)
# Requirement already satisfied: requests in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from keras_tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from keras_tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests->keras_tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests->keras_tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests->keras_tuner) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from requests->keras_tuner) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.1)
# Requirement already satisfied: six>=1.5 in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tabulate in c:\users\matthew chuang\documents\github\csc3009-brain-tumor-detection\dependencies\lib\site-packages (0.9.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import numpy as np
# Machine Learning
import tensorflow as tf
from tensorflow.keras.applications import VGG16, VGG19
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import keras_tuner as kt
# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.metrics import Precision, Recall
from tabulate import tabulate
import pandas as pd

# %% [markdown]
# ### Optional: GPU Acceleration Check
# Checks Tensorflow Version and GPU detection.
# If GPU detected, output should be something like "Num GPUs Available:  1"

# %%
print("TensorFlow version:", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
physical_devices = tf.config.list_physical_devices()
print("Physical Devices:", physical_devices)
# Out:
# TensorFlow version: 2.10.0
# Num GPUs Available:  1
# Physical Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Load and Split Prepared Data
# Loads in preprocessed data from the ./prepared_data directory for x and y features.

# %%
# Load the data
x_input = np.load('prepared_data/x_input_combined.npy')
y_output = np.load('prepared_data/y_output_combined.npy')

# Set seed for reproducibility
seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
# 3. Set the NumPy random seed
np.random.seed(seed_value)
# 4. Set the TensorFlow random seed
tf.random.set_seed(seed_value)

# Ensure y is output hot coded
y_output = to_categorical(y_output, num_classes=4)
# Resizes images to 224 x 224 for optimal size for VGG models
# x_input_resized = np.array([tf.image.resize(image, (224, 224)).numpy() for image in x_input])

# %% [markdown]
# Splits for training and testing 80/20 ratio

# %%
# Split the data into training and testing sets
x_input_train, x_input_test, y_output_train, y_output_test = train_test_split(x_input, y_output, test_size=0.2, random_state=seed_value)

# Printing Dimensions of data
print(f'X Training Data\nNumber of Rows: {x_input_train.shape[0]}\nPixel Dimensions: {x_input_train.shape[1]}x{x_input_train.shape[2]}x{x_input_train.shape[3]}\n')
print(f'Y Training Data\nNumber of Rows: {y_output_train.shape[0]}\nNumber of Classes: {y_output_train.shape[1]}\n')
print(f'X Testing Data\nNumber of Rows: {x_input_test.shape[0]}\nPixel Dimensions: {x_input_test.shape[1]}x{x_input_test.shape[2]}x{x_input_test.shape[3]}\n')
print(f'Y Training Data\nNumber of Rows: {y_output_test.shape[0]}\nNumber of Classes: {y_output_test.shape[1]}')
# Out:
# X Training Data
# Number of Rows: 1536
# Pixel Dimensions: 224x224x3
#
# Y Training Data
# Number of Rows: 1536
# Number of Classes: 4
#
# X Testing Data
# Number of Rows: 384
# Pixel Dimensions: 224x224x3
#
# Y Training Data
# Number of Rows: 384
# Number of Classes: 4

# %% [markdown]
# ### Optional: Hyperparameter Optimisation
# For the most optimal parameters (neurons, dropouts, learning rates), the Keras Tuner was used on the VGG16 model which was less computationally expensive than its VGG19 counterpart. One function was used to create the model, the other to define how the tuning was done.
#
# The output of the Hyperparameter Optimisation were as follows
# * 640 neurons for first dense layer
# * 0.2 dropout rate for first dropout layer
# * 512 neurons for second dense layer
# * 0.4 dropout rate for both second dropout layer
# * 0.0005 learning rate
#
# These hyperparameters were used for both the VGG16 & VGG19 models

# %%
# # Function to build the model
# def build_model(hp):
#     base_vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
#     for layer in base_vgg16_model.layers:
#         layer.trainable = False

#     x = base_vgg16_model.output
#     x = GlobalAveragePooling2D()(x)
#     x = BatchNormalization()(x)
    
#     # Tune the number of units in the first dense layer
#     units_1 = hp.Int('units_1', min_value=512, max_value=1024, step=128)
#     x = Dense(units_1, activation='relu', kernel_constraint=max_norm(3))(x)
    
#     # Tune the dropout rate
#     dropout_1 = hp.Float('dropout_1', min_value=0.0, max_value=0.5, step=0.1)
#     x = Dropout(dropout_1)(x)
    
#     # Tune the number of units in the second dense layer
#     units_2 = hp.Int('units_2', min_value=256, max_value=512, step=128)
#     x = Dense(units_2, activation='relu', kernel_constraint=max_norm(3))(x)
    
#     # Tune the dropout rate
#     dropout_2 = hp.Float('dropout_2', min_value=0.0, max_value=0.5, step=0.1)
#     x = Dropout(dropout_2)(x)
    
#     new_output_layer_vgg16 = Dense(4, activation='softmax')(x)  # 4 classes: no tumor, glioma, meningioma, pituitary
    
#     model = Model(inputs=base_vgg16_model.input, outputs=new_output_layer_vgg16)
    
#     # Tune the learning rate
#     learning_rate = hp.Choice('learning_rate', values=[1e-2, 5e-3, 1e-3, 5e-4])
#     model.compile(optimizer=Adam(learning_rate=learning_rate),
#                 loss='categorical_crossentropy',
#                 metrics=['accuracy'])
    
#     return model

# %%
# # Set up the tuner
# tuner = kt.RandomSearch(
#     build_model,
#     objective='val_accuracy',
#     max_trials=30,
#     executions_per_trial=1,
#     directory='kt_tuning/kt_tuner_vggtest',
#     project_name='brain_tumor_classification'
# )

# # Define callbacks
# checkpoint = ModelCheckpoint('model_checkpoints/vgg16_best_model.keras', monitor='val_loss', save_best_only=True, verbose=1)
# early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

# # Run the hyperparameter search
# tuner.search(x_input_train, y_output_train, epochs=50, validation_data=(x_input_test, y_output_test), callbacks=[checkpoint, early_stopping])

# # Get the optimal hyperparameters
# best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# print(f"""
# The optimal number of units in the first dense layer is {best_hps.get('units_1')}.
# The optimal dropout rate for the first dropout layer is {best_hps.get('dropout_1')}.
# The optimal number of units in the second dense layer is {best_hps.get('units_2')}.
# The optimal dropout rate for the second dropout layer is {best_hps.get('dropout_2')}.
# The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
# """)

# %% [markdown]
# ### Define VGG Models
# In this segment, pretrained VGG models are called from TensorFlow. These models are configured to receive its weightages trained from the ImageNet dataset and to receive a 224x224x3 image input. The top layer is also removed for further improvements.
# * weights='imagenet' > Loads weightages from ImageNet data training
# * include_top = False > Exclude top layers of model, to add custom top layers (tuning with our data)
# * input_shape > Specify the dimensions of our input data, which is given as 224 x 224 pixels and 3 representing color channels in each image (RGB)

# %% [markdown]
# #### Defining Model VGG16

# %%
# Load the VGG16 model pre-trained on ImageNet
base_vgg16_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %% [markdown]
# In place of the last layer that was dropped, new layers are defined to fine tune the base model to our use case. These layers will have their weights altered based on the data we train it on. For other model layers, they are frozen to prevent any amendments to weightage.
#
# Resources for Layering Operations:
# * How Global Average Pooling works: https://saturncloud.io/blog/understanding-the-difference-between-flatten-and-globalaveragepooling2d-in-keras/#:~:text=with%20nine%20elements.-,What%20is%20GlobalAveragePooling2D()%20in%20Keras%3F,an%20operation%20on%20the%20data.
# * How Batch Normalisation works: https://arxiv.org/abs/1502.03167
# * How kernal constraints works: https://keras.io/api/layers/constraints/#:~:text=MaxNorm%20class&text=Constrains%20the%20weights%20incident%20to,max_norm%20.
# * How dropout layers works: https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dropout#:~:text=The%20Dropout%20layer%20randomly%20sets,over%20all%20inputs%20is%20unchanged.

# %%
# Adds average pool layer to reduce dimensionality of feature maps
new_layers_vgg16 = GlobalAveragePooling2D()(base_vgg16_model.output)
# Adds a normalisation layer to enhance performance with bigger batch sizes (32)
new_layers_vgg16 = BatchNormalization()(new_layers_vgg16)
# Add first dense layer of 1024 neurons with RELU, adds weight constraints, regularising weights directly
new_layers_vgg16 = Dense(640, activation='relu', kernel_constraint=max_norm(3))(new_layers_vgg16)
# Add first dropout layer with 20% dropout rate to avoid overfitting   
new_layers_vgg16 = Dropout(0.2)(new_layers_vgg16)
# Add second dense layer of 384 neurons with RELU, adds weight constraints, regularising weights directly
new_layers_vgg16 = Dense(512, activation='relu', kernel_constraint=max_norm(3))(new_layers_vgg16)
# Add second dropout layer with 20% dropout rate to avoid overfitting  
new_layers_vgg16 = Dropout(0.4)(new_layers_vgg16)
# Add final output layer with four neurons corresponding to four classes with activation as softmax to predict probability of each class
output_layer_vgg16 = Dense(4, activation='softmax')(new_layers_vgg16)

# Define the model
vgg16_model = Model(inputs=base_vgg16_model.input, outputs=output_layer_vgg16)

# Freeze the layers of the base model
for layer in base_vgg16_model.layers:
    layer.trainable = False

# %% [markdown]
# #### Defining Model VGG19

# %%
# Load the VGG19 model pre-trained on ImageNet 
base_vgg19_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# Adds average pool layer to reduce dimensionality of feature maps
new_layers_vgg19 = GlobalAveragePooling2D()(base_vgg19_model.output)
# Adds a normalisation layer to enhance performance with bigger batch sizes (32)
new_layers_vgg19 = BatchNormalization()(new_layers_vgg19)
# Add first dense layer of 1024 neurons with RELU, adds weight constraints, regularising weights directly
new_layers_vgg19 = Dense(640, activation='relu', kernel_constraint=max_norm(3))(new_layers_vgg19)
# Add first dropout layer with 20% dropout rate to avoid overfitting   
new_layers_vgg19 = Dropout(0.2)(new_layers_vgg19)
# Add second dense layer of 384 neurons with RELU, adds weight constraints, regularising weights directly
new_layers_vgg19 = Dense(512, activation='relu', kernel_constraint=max_norm(3))(new_layers_vgg19)
# Add second dropout layer with 20% dropout rate to avoid overfitting  
new_layers_vgg19 = Dropout(0.4)(new_layers_vgg19)
# Add final output layer with four neurons corresponding to four classes with activation as softmax to predict probability of each class
output_layer_vgg19 = Dense(4, activation='softmax')(new_layers_vgg19)

# Define the model
vgg19_model = Model(inputs=base_vgg19_model.input, outputs=output_layer_vgg19)

# Freeze the layers of the base model
for layer in base_vgg19_model.layers:
    layer.trainable = False

# %% [markdown]
# ### Training the VGG Models
# In this segment, the models were configured to be compiled using the
# * Adam's Optimizer
# * Categorical Cross Entropy for Multi-Class Classification
# * Accuracy
#
# Checkpoints were defined to save best models based on validation loss.

# %% [markdown]
# #### Training Model VGG16

# %%
# Compile the model
vgg16_model.compile(optimizer=Adam(learning_rate=0.0005), loss='categorical_crossentropy', metrics=['accuracy', Precision(name='precision'), Recall(name='recall')])

# Define callbacks for early stopping, best model saving to ./model_checkpoints
checkpoint_vgg16 = ModelCheckpoint('model_checkpoints/vgg16_brain_tumor.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stopping_vgg16 = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

# Train the model
vgg16_history = vgg16_model.fit(x_input_train, y_output_train, epochs=50, validation_data=(x_input_test, y_output_test), 
                    callbacks=[checkpoint_vgg16, early_stopping_vgg16])
# Out:
# Epoch 1/50
# 48/48 [==============================] - ETA: 0s - loss: 0.7666 - accuracy: 0.6992 - precision: 0.7822 - recall: 0.6055
# Epoch 1: val_loss improved from inf to 1.20542, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 5s 79ms/step - loss: 0.7666 - accuracy: 0.6992 - precision: 0.7822 - recall: 0.6055 - val_loss: 1.2054 - val_accuracy: 0.3568 - val_precision: 0.8571 - val_recall: 0.0781
# Epoch 2/50
# 48/48 [==============================] - ETA: 0s - loss: 0.3739 - accuracy: 0.8665 - precision: 0.8916 - recall: 0.8411
# Epoch 2: val_loss improved from 1.20542 to 1.04212, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.3739 - accuracy: 0.8665 - precision: 0.8916 - recall: 0.8411 - val_loss: 1.0421 - val_accuracy: 0.5182 - val_precision: 0.8875 - val_recall: 0.1849
# Epoch 3/50
# 48/48 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9310 - precision: 0.9460 - recall: 0.9128
# Epoch 3: val_loss improved from 1.04212 to 0.83872, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.2217 - accuracy: 0.9310 - precision: 0.9460 - recall: 0.9128 - val_loss: 0.8387 - val_accuracy: 0.7734 - val_precision: 0.9569 - val_recall: 0.2891
# Epoch 4/50
# 48/48 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.9557 - precision: 0.9630 - recall: 0.9492
# Epoch 4: val_loss improved from 0.83872 to 0.67489, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.1465 - accuracy: 0.9557 - precision: 0.9630 - recall: 0.9492 - val_loss: 0.6749 - val_accuracy: 0.8307 - val_precision: 0.9690 - val_recall: 0.5703
# Epoch 5/50
# 48/48 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9544 - precision: 0.9574 - recall: 0.9512
# Epoch 5: val_loss improved from 0.67489 to 0.52367, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 75ms/step - loss: 0.1221 - accuracy: 0.9544 - precision: 0.9574 - recall: 0.9512 - val_loss: 0.5237 - val_accuracy: 0.8542 - val_precision: 0.9251 - val_recall: 0.7396
# Epoch 6/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9805 - precision: 0.9804 - recall: 0.9759
# Epoch 6: val_loss improved from 0.52367 to 0.33590, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0708 - accuracy: 0.9805 - precision: 0.9804 - recall: 0.9759 - val_loss: 0.3359 - val_accuracy: 0.9323 - val_precision: 0.9547 - val_recall: 0.8776
# Epoch 7/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0752 - accuracy: 0.9753 - precision: 0.9758 - recall: 0.9733
# Epoch 7: val_loss improved from 0.33590 to 0.25751, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0752 - accuracy: 0.9753 - precision: 0.9758 - recall: 0.9733 - val_loss: 0.2575 - val_accuracy: 0.9401 - val_precision: 0.9615 - val_recall: 0.9115
# Epoch 8/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0558 - accuracy: 0.9824 - precision: 0.9837 - recall: 0.9798
# Epoch 8: val_loss improved from 0.25751 to 0.19974, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0558 - accuracy: 0.9824 - precision: 0.9837 - recall: 0.9798 - val_loss: 0.1997 - val_accuracy: 0.9427 - val_precision: 0.9571 - val_recall: 0.9297
# Epoch 9/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9961 - precision: 0.9967 - recall: 0.9941
# Epoch 9: val_loss improved from 0.19974 to 0.16614, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0280 - accuracy: 0.9961 - precision: 0.9967 - recall: 0.9941 - val_loss: 0.1661 - val_accuracy: 0.9505 - val_precision: 0.9577 - val_recall: 0.9427
# Epoch 10/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9863 - precision: 0.9863 - recall: 0.9857
# Epoch 10: val_loss improved from 0.16614 to 0.14757, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0341 - accuracy: 0.9863 - precision: 0.9863 - recall: 0.9857 - val_loss: 0.1476 - val_accuracy: 0.9557 - val_precision: 0.9657 - val_recall: 0.9531
# Epoch 11/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967
# Epoch 11: val_loss improved from 0.14757 to 0.14071, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0195 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.1407 - val_accuracy: 0.9531 - val_precision: 0.9580 - val_recall: 0.9505
# Epoch 12/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9928 - precision: 0.9928 - recall: 0.9928
# Epoch 12: val_loss improved from 0.14071 to 0.13531, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0232 - accuracy: 0.9928 - precision: 0.9928 - recall: 0.9928 - val_loss: 0.1353 - val_accuracy: 0.9635 - val_precision: 0.9658 - val_recall: 0.9557
# Epoch 13/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9889
# Epoch 13: val_loss did not improve from 0.13531
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0282 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9889 - val_loss: 0.1676 - val_accuracy: 0.9609 - val_precision: 0.9634 - val_recall: 0.9583
# Epoch 14/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9935 - precision: 0.9941 - recall: 0.9922
# Epoch 14: val_loss improved from 0.13531 to 0.13187, saving model to model_checkpoints\vgg16_brain_tumor.keras
# 48/48 [==============================] - 4s 74ms/step - loss: 0.0236 - accuracy: 0.9935 - precision: 0.9941 - recall: 0.9922 - val_loss: 0.1319 - val_accuracy: 0.9609 - val_precision: 0.9608 - val_recall: 0.9583
# Epoch 15/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909
# Epoch 15: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0279 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - val_loss: 0.1401 - val_accuracy: 0.9557 - val_precision: 0.9633 - val_recall: 0.9557
# Epoch 16/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9831
# Epoch 16: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 71ms/step - loss: 0.0503 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9831 - val_loss: 0.1804 - val_accuracy: 0.9609 - val_precision: 0.9632 - val_recall: 0.9531
# Epoch 17/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9935
# Epoch 17: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 71ms/step - loss: 0.0213 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9935 - val_loss: 0.1709 - val_accuracy: 0.9531 - val_precision: 0.9606 - val_recall: 0.9531
# Epoch 18/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9909 - precision: 0.9915 - recall: 0.9909
# Epoch 18: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 71ms/step - loss: 0.0215 - accuracy: 0.9909 - precision: 0.9915 - recall: 0.9909 - val_loss: 0.1592 - val_accuracy: 0.9635 - val_precision: 0.9635 - val_recall: 0.9635
# Epoch 19/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9928 - precision: 0.9928 - recall: 0.9922
# Epoch 19: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0308 - accuracy: 0.9928 - precision: 0.9928 - recall: 0.9922 - val_loss: 0.2429 - val_accuracy: 0.9427 - val_precision: 0.9427 - val_recall: 0.9427
# Epoch 20/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9941
# Epoch 20: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0197 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9941 - val_loss: 0.2916 - val_accuracy: 0.9375 - val_precision: 0.9399 - val_recall: 0.9375
# Epoch 21/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909
# Epoch 21: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 73ms/step - loss: 0.0256 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - val_loss: 0.1828 - val_accuracy: 0.9609 - val_precision: 0.9633 - val_recall: 0.9557
# Epoch 22/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9902 - precision: 0.9909 - recall: 0.9902
# Epoch 22: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 72ms/step - loss: 0.0295 - accuracy: 0.9902 - precision: 0.9909 - recall: 0.9902 - val_loss: 0.2086 - val_accuracy: 0.9531 - val_precision: 0.9530 - val_recall: 0.9505
# Epoch 23/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9928 - precision: 0.9928 - recall: 0.9928
# Epoch 23: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 71ms/step - loss: 0.0225 - accuracy: 0.9928 - precision: 0.9928 - recall: 0.9928 - val_loss: 0.2183 - val_accuracy: 0.9479 - val_precision: 0.9478 - val_recall: 0.9453
# Epoch 24/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9941
# Epoch 24: val_loss did not improve from 0.13187
# 48/48 [==============================] - 3s 70ms/step - loss: 0.0147 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9941 - val_loss: 0.2328 - val_accuracy: 0.9557 - val_precision: 0.9555 - val_recall: 0.9505
# Epoch 24: early stopping

# %% [markdown]
# #### Training Model VGG19

# %%
# Compile the model
vgg19_model.compile(optimizer=Adam(learning_rate=0.0005), loss='categorical_crossentropy', metrics=['accuracy', Precision(name="precision"), Recall(name="recall")])

# Define callbacks
checkpoint_vgg19 = ModelCheckpoint('model_checkpoints/vgg19_brain_tumor.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stopping_vgg19 = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

# Train the model
vgg19_history = vgg19_model.fit(x_input_train, y_output_train, epochs=50, validation_data=(x_input_test, y_output_test), 
                    callbacks=[checkpoint_vgg19, early_stopping_vgg19])
# Out:
# Epoch 1/50
# 48/48 [==============================] - ETA: 0s - loss: 0.7698 - accuracy: 0.6960 - precision: 0.7732 - recall: 0.6016
# Epoch 1: val_loss improved from inf to 1.17450, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 5s 93ms/step - loss: 0.7698 - accuracy: 0.6960 - precision: 0.7732 - recall: 0.6016 - val_loss: 1.1745 - val_accuracy: 0.4635 - val_precision: 1.0000 - val_recall: 0.0182
# Epoch 2/50
# 48/48 [==============================] - ETA: 0s - loss: 0.4286 - accuracy: 0.8464 - precision: 0.8761 - recall: 0.8099
# Epoch 2: val_loss improved from 1.17450 to 1.07192, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 85ms/step - loss: 0.4286 - accuracy: 0.8464 - precision: 0.8761 - recall: 0.8099 - val_loss: 1.0719 - val_accuracy: 0.5417 - val_precision: 0.8750 - val_recall: 0.1458
# Epoch 3/50
# 48/48 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.9121 - precision: 0.9317 - recall: 0.8887
# Epoch 3: val_loss improved from 1.07192 to 0.94662, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 87ms/step - loss: 0.2829 - accuracy: 0.9121 - precision: 0.9317 - recall: 0.8887 - val_loss: 0.9466 - val_accuracy: 0.6198 - val_precision: 0.8705 - val_recall: 0.3151
# Epoch 4/50
# 48/48 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9355 - precision: 0.9465 - recall: 0.9219
# Epoch 4: val_loss improved from 0.94662 to 0.74621, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 85ms/step - loss: 0.1899 - accuracy: 0.9355 - precision: 0.9465 - recall: 0.9219 - val_loss: 0.7462 - val_accuracy: 0.7865 - val_precision: 0.9378 - val_recall: 0.4714
# Epoch 5/50
# 48/48 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9538 - precision: 0.9598 - recall: 0.9473
# Epoch 5: val_loss improved from 0.74621 to 0.58196, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 86ms/step - loss: 0.1396 - accuracy: 0.9538 - precision: 0.9598 - recall: 0.9473 - val_loss: 0.5820 - val_accuracy: 0.8438 - val_precision: 0.9203 - val_recall: 0.6615
# Epoch 6/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9674 - precision: 0.9718 - recall: 0.9635
# Epoch 6: val_loss improved from 0.58196 to 0.42874, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 85ms/step - loss: 0.0967 - accuracy: 0.9674 - precision: 0.9718 - recall: 0.9635 - val_loss: 0.4287 - val_accuracy: 0.8906 - val_precision: 0.9325 - val_recall: 0.7917
# Epoch 7/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9720 - precision: 0.9757 - recall: 0.9674
# Epoch 7: val_loss improved from 0.42874 to 0.35877, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 86ms/step - loss: 0.0894 - accuracy: 0.9720 - precision: 0.9757 - recall: 0.9674 - val_loss: 0.3588 - val_accuracy: 0.8802 - val_precision: 0.9200 - val_recall: 0.8385
# Epoch 8/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.9811 - precision: 0.9811 - recall: 0.9792
# Epoch 8: val_loss improved from 0.35877 to 0.25907, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 86ms/step - loss: 0.0696 - accuracy: 0.9811 - precision: 0.9811 - recall: 0.9792 - val_loss: 0.2591 - val_accuracy: 0.9271 - val_precision: 0.9425 - val_recall: 0.8958
# Epoch 9/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9798 - precision: 0.9810 - recall: 0.9772
# Epoch 9: val_loss improved from 0.25907 to 0.19576, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 85ms/step - loss: 0.0565 - accuracy: 0.9798 - precision: 0.9810 - recall: 0.9772 - val_loss: 0.1958 - val_accuracy: 0.9323 - val_precision: 0.9342 - val_recall: 0.9245
# Epoch 10/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9818
# Epoch 10: val_loss improved from 0.19576 to 0.18994, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 85ms/step - loss: 0.0503 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9818 - val_loss: 0.1899 - val_accuracy: 0.9271 - val_precision: 0.9491 - val_recall: 0.9219
# Epoch 11/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9831 - precision: 0.9850 - recall: 0.9811
# Epoch 11: val_loss improved from 0.18994 to 0.16321, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 83ms/step - loss: 0.0469 - accuracy: 0.9831 - precision: 0.9850 - recall: 0.9811 - val_loss: 0.1632 - val_accuracy: 0.9375 - val_precision: 0.9446 - val_recall: 0.9323
# Epoch 12/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9928
# Epoch 12: val_loss did not improve from 0.16321
# 48/48 [==============================] - 4s 81ms/step - loss: 0.0305 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9928 - val_loss: 0.1689 - val_accuracy: 0.9505 - val_precision: 0.9554 - val_recall: 0.9479
# Epoch 13/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889
# Epoch 13: val_loss did not improve from 0.16321
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0358 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - val_loss: 0.1865 - val_accuracy: 0.9375 - val_precision: 0.9519 - val_recall: 0.9271
# Epoch 14/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974
# Epoch 14: val_loss improved from 0.16321 to 0.15441, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 82ms/step - loss: 0.0162 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9974 - val_loss: 0.1544 - val_accuracy: 0.9505 - val_precision: 0.9529 - val_recall: 0.9479
# Epoch 15/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9967
# Epoch 15: val_loss improved from 0.15441 to 0.13160, saving model to model_checkpoints\vgg19_brain_tumor.keras
# 48/48 [==============================] - 4s 82ms/step - loss: 0.0190 - accuracy: 0.9974 - precision: 0.9974 - recall: 0.9967 - val_loss: 0.1316 - val_accuracy: 0.9557 - val_precision: 0.9555 - val_recall: 0.9505
# Epoch 16/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0323 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9870
# Epoch 16: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0323 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9870 - val_loss: 0.2062 - val_accuracy: 0.9427 - val_precision: 0.9426 - val_recall: 0.9401
# Epoch 17/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9811 - precision: 0.9811 - recall: 0.9811
# Epoch 17: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 81ms/step - loss: 0.0438 - accuracy: 0.9811 - precision: 0.9811 - recall: 0.9811 - val_loss: 0.1832 - val_accuracy: 0.9531 - val_precision: 0.9555 - val_recall: 0.9505
# Epoch 18/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9915 - precision: 0.9928 - recall: 0.9915
# Epoch 18: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 81ms/step - loss: 0.0232 - accuracy: 0.9915 - precision: 0.9928 - recall: 0.9915 - val_loss: 0.1601 - val_accuracy: 0.9531 - val_precision: 0.9580 - val_recall: 0.9505
# Epoch 19/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9928
# Epoch 19: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0234 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9928 - val_loss: 0.2993 - val_accuracy: 0.9245 - val_precision: 0.9245 - val_recall: 0.9245
# Epoch 20/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909
# Epoch 20: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0314 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - val_loss: 0.3001 - val_accuracy: 0.9219 - val_precision: 0.9217 - val_recall: 0.9193
# Epoch 21/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9896 - precision: 0.9902 - recall: 0.9889
# Epoch 21: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0488 - accuracy: 0.9896 - precision: 0.9902 - recall: 0.9889 - val_loss: 0.2375 - val_accuracy: 0.9453 - val_precision: 0.9452 - val_recall: 0.9427
# Epoch 22/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9961 - precision: 0.9961 - recall: 0.9961
# Epoch 22: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0179 - accuracy: 0.9961 - precision: 0.9961 - recall: 0.9961 - val_loss: 0.1774 - val_accuracy: 0.9505 - val_precision: 0.9530 - val_recall: 0.9505
# Epoch 23/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967
# Epoch 23: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0119 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967 - val_loss: 0.2432 - val_accuracy: 0.9401 - val_precision: 0.9450 - val_recall: 0.9401
# Epoch 24/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9922 - precision: 0.9922 - recall: 0.9922
# Epoch 24: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 80ms/step - loss: 0.0203 - accuracy: 0.9922 - precision: 0.9922 - recall: 0.9922 - val_loss: 0.2537 - val_accuracy: 0.9401 - val_precision: 0.9450 - val_recall: 0.9401
# Epoch 25/50
# 48/48 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9935
# Epoch 25: val_loss did not improve from 0.13160
# 48/48 [==============================] - 4s 81ms/step - loss: 0.0176 - accuracy: 0.9941 - precision: 0.9941 - recall: 0.9935 - val_loss: 0.2030 - val_accuracy: 0.9557 - val_precision: 0.9557 - val_recall: 0.9557
# Epoch 25: early stopping

# %% [markdown]
# ### Evaluation using Model Performance & Classification Metrics
# Overall model Performance to be Plotted using Training/Validation over Epoches
# * Loss
# * Accuracy
# * Precision
# * Recall
#
# These model performance will be further drilled down in the confusion matrix and the classification report, where we will observe numbers for
# * True Positive
# * True Negatives
# * False Positives
# * False Negatives

# %%
def plot_model_performance(history, title):
    """Plot training and validation loss, accuracy, precision, and recall, and print metrics in a table format."""
    epochs = range(1, len(history.history['loss']) + 1)
    data = {
        'Epoch': epochs,
        'Training Loss': history.history['loss'],
        'Validation Loss': history.history['val_loss'],
        'Training Accuracy': history.history['accuracy'],
        'Validation Accuracy': history.history['val_accuracy'],
        'Training Precision': history.history['precision'],
        'Validation Precision': history.history['val_precision'],
        'Training Recall': history.history['recall'],
        'Validation Recall': history.history['val_recall']
    }
    df = pd.DataFrame(data)
    
    # Print the metrics in a table format using tabulate
    print(tabulate(df, headers='keys', tablefmt='pretty'))
    
    plt.figure(figsize=(10, 20))  # Adjust the figure size for better visibility

    # Plot loss
    plt.subplot(4, 1, 1)  # 4 rows, 1 column, first subplot
    plt.plot(epochs, history.history['loss'], label='Training Loss')
    plt.plot(epochs, history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot accuracy
    plt.subplot(4, 1, 2)  # 4 rows, 1 column, second subplot
    plt.plot(epochs, history.history['accuracy'], label='Training Accuracy')
    plt.plot(epochs, history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim(0, 1)  # Fix the accuracy scale from 0 to 1
    plt.yticks([i / 10.0 for i in range(11)])  # Set y-ticks to show labels at intervals of 0.1
    plt.legend()
    plt.grid(True)

    # Plot precision
    plt.subplot(4, 1, 3)  # 4 rows, 1 column, third subplot
    plt.plot(epochs, history.history['precision'], label='Training Precision')
    plt.plot(epochs, history.history['val_precision'], label='Validation Precision')
    plt.title('Training and Validation Precision')
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.ylim(0, 1)  # Fix the precision scale from 0 to 1
    plt.yticks([i / 10.0 for i in range(11)])  # Set y-ticks to show labels at intervals of 0.1
    plt.legend()
    plt.grid(True)

    # Plot recall
    plt.subplot(4, 1, 4)  # 4 rows, 1 column, fourth subplot
    plt.plot(epochs, history.history['recall'], label='Training Recall')
    plt.plot(epochs, history.history['val_recall'], label='Validation Recall')
    plt.title('Training and Validation Recall')
    plt.xlabel('Epochs')
    plt.ylabel('Recall')
    plt.ylim(0, 1)  # Fix the recall scale from 0 to 1
    plt.yticks([i / 10.0 for i in range(11)])  # Set y-ticks to show labels at intervals of 0.1
    plt.legend()
    plt.grid(True)

    plt.suptitle(title)
    plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to make space for the title
    plt.show()

def plot_confusion_matrix(model):
    """Evaluate a trained model on test data and display the confusion matrix and classification report."""
    # Class labels
    class_names = ['glioma', 'meningioma', 'notumor', 'pituitary']
    # Predict the labels for the test data
    predictions = model.predict(x_input_test)
    predicted_labels = np.argmax(predictions, axis=1)
    true_labels = np.argmax(y_output_test, axis=1)
    
    # Compute the confusion matrix
    conf_matrix = confusion_matrix(true_labels, predicted_labels)
    
    # Plot the confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    
    # Print the classification report using tabulate
    report = classification_report(true_labels, predicted_labels, target_names=class_names, output_dict=True)
    report_df = pd.DataFrame(report).transpose()
    
    print("Classification Report:")
    print(tabulate(report_df, headers='keys', tablefmt='pretty'))

# %% [markdown]
# #### Simple & Classification Metrics for Model VGG16

# %%
plot_model_performance(vgg16_history, "Performance History for current VGG16 iteration")
best_vgg16_model = load_model('model_checkpoints/vgg16_brain_tumor.keras')
plot_confusion_matrix(best_vgg16_model)
# Out:
# +----+-------+----------------------+---------------------+--------------------+---------------------+--------------------+----------------------+--------------------+--------------------+
# |    | Epoch |    Training Loss     |   Validation Loss   | Training Accuracy  | Validation Accuracy | Training Precision | Validation Precision |  Training Recall   | Validation Recall  |
# +----+-------+----------------------+---------------------+--------------------+---------------------+--------------------+----------------------+--------------------+--------------------+
# | 0  |  1.0  |  0.7666248679161072  | 1.2054191827774048  |     0.69921875     | 0.3567708432674408  | 0.7821698784828186 |  0.8571428656578064  |     0.60546875     |      0.078125      |
# | 1  |  2.0  |  0.3739255666732788  | 1.0421174764633179  | 0.8665364384651184 | 0.5182291865348816  | 0.8916494250297546 |  0.887499988079071   | 0.8411458134651184 | 0.1848958283662796 |
# | 2  |  3.0  | 0.22167693078517914  |  0.838720977306366  | 0.9309895634651184 |      0.7734375      | 0.9460188746452332 |  0.9568965435028076  | 0.9127604365348816 |     0.2890625      |
# | 3  |  4.0  |  0.1464615911245346  | 0.6748946309089661  | 0.9557291865348816 | 0.8307291865348816  | 0.9630118608474731 |  0.9690265655517578  |     0.94921875     |     0.5703125      |
# | 4  |  5.0  | 0.12212676554918289  | 0.5236667990684509  | 0.9544270634651184 | 0.8541666865348816  | 0.9574049711227417 |  0.9250814318656921  |    0.951171875     | 0.7395833134651184 |
# | 5  |  6.0  | 0.07081824541091919  | 0.3359009921550751  |     0.98046875     | 0.9322916865348816  | 0.9803793430328369 |  0.954674243927002   | 0.9759114384651184 | 0.8776041865348816 |
# | 6  |  7.0  | 0.07518269866704941  | 0.2575148046016693  | 0.9752604365348816 | 0.9401041865348816  | 0.9758485555648804 |  0.9615384340286255  | 0.9733073115348816 | 0.9114583134651184 |
# | 7  |  8.0  | 0.055820319801568985 |  0.199743390083313  |    0.982421875     | 0.9427083134651184  | 0.983660101890564  |  0.9571045637130737  | 0.9798176884651184 |     0.9296875      |
# | 8  |  9.0  | 0.027974752709269524 | 0.1661413311958313  |     0.99609375     | 0.9505208134651184  | 0.9967362880706787 |  0.9576719403266907  |    0.994140625     | 0.9427083134651184 |
# | 9  | 10.0  | 0.03408936783671379  | 0.14756804704666138 |    0.986328125     | 0.9557291865348816  | 0.9863192439079285 |  0.9656991958618164  | 0.9856770634651184 |      0.953125      |
# | 10 | 11.0  | 0.01950385607779026  | 0.14071212708950043 | 0.9967448115348816 |      0.953125       | 0.9967448115348816 |  0.9580052495002747  | 0.9967448115348816 | 0.9505208134651184 |
# | 11 | 12.0  | 0.023228272795677185 | 0.1353071630001068  | 0.9928385615348816 | 0.9635416865348816  | 0.9928385615348816 |  0.9657894968986511  | 0.9928385615348816 | 0.9557291865348816 |
# | 12 | 13.0  | 0.02817733772099018  | 0.16760508716106415 | 0.9908854365348816 |      0.9609375      | 0.990867555141449  |  0.963350772857666   | 0.9889323115348816 | 0.9583333134651184 |
# | 13 | 14.0  | 0.023579241707921028 | 0.13186736404895782 | 0.9934895634651184 |      0.9609375      | 0.9941291809082031 |  0.9608355164527893  |     0.9921875      | 0.9583333134651184 |
# | 14 | 15.0  | 0.027940846979618073 | 0.14011676609516144 | 0.9908854365348816 | 0.9557291865348816  | 0.9908854365348816 |  0.9632545709609985  | 0.9908854365348816 | 0.9557291865348816 |
# | 15 | 16.0  | 0.05032046139240265  | 0.18044781684875488 | 0.9850260615348816 |      0.9609375      | 0.9849967360496521 |  0.9631578922271729  | 0.9830729365348816 |      0.953125      |
# | 16 | 17.0  | 0.02126888930797577  | 0.17089082300662994 | 0.9934895634651184 |      0.953125       | 0.9934895634651184 |  0.960629940032959   | 0.9934895634651184 |      0.953125      |
# | 17 | 18.0  | 0.021510684862732887 | 0.15919135510921478 | 0.9908854365348816 | 0.9635416865348816  | 0.9915309548377991 |  0.9635416865348816  | 0.9908854365348816 | 0.9635416865348816 |
# | 18 | 19.0  | 0.030848992988467216 | 0.24289119243621826 | 0.9928385615348816 | 0.9427083134651184  | 0.9928338527679443 |  0.9427083134651184  |     0.9921875      | 0.9427083134651184 |
# | 19 | 20.0  | 0.019700607284903526 |  0.291613906621933  |    0.994140625     |       0.9375        |    0.994140625     |  0.939947783946991   |    0.994140625     |       0.9375       |
# | 20 | 21.0  | 0.025607742369174957 | 0.1828145533800125  | 0.9908854365348816 |      0.9609375      | 0.9908854365348816 |  0.9632545709609985  | 0.9908854365348816 | 0.9557291865348816 |
# | 21 | 22.0  | 0.029513461515307426 | 0.2085815817117691  |    0.990234375     |      0.953125       | 0.990879476070404  |  0.9530026316642761  |    0.990234375     | 0.9505208134651184 |
# | 22 | 23.0  | 0.022530676797032356 |  0.218306764960289  | 0.9928385615348816 | 0.9479166865348816  | 0.9928385615348816 |  0.9477806687355042  | 0.9928385615348816 |     0.9453125      |
# | 23 | 24.0  | 0.014688614755868912 | 0.23278813064098358 |    0.994140625     | 0.9557291865348816  |    0.994140625     |  0.9554973840713501  |    0.994140625     | 0.9505208134651184 |
# +----+-------+----------------------+---------------------+--------------------+---------------------+--------------------+----------------------+--------------------+--------------------+
# 12/12 [==============================] - 1s 55ms/step
# Classification Report:
# +--------------+--------------------+--------------------+--------------------+-----------+
# |              |     precision      |       recall       |      f1-score      |  support  |
# +--------------+--------------------+--------------------+--------------------+-----------+
# |    glioma    | 0.978494623655914  | 0.978494623655914  | 0.978494623655914  |   93.0    |
# |  meningioma  |        1.0         | 0.9069767441860465 | 0.9512195121951219 |   86.0    |
# |   notumor    | 0.9316239316239316 | 0.9732142857142857 | 0.9519650655021834 |   112.0   |
# |  pituitary   | 0.9479166666666666 | 0.978494623655914  | 0.9629629629629629 |   93.0    |
# |   accuracy   |     0.9609375      |     0.9609375      |     0.9609375      | 0.9609375 |
# |  macro avg   | 0.9645088054866281 |  0.95929506930304  | 0.9611605410790456 |   384.0   |
# | weighted avg | 0.9622347144319802 |     0.9609375      | 0.9608867732827618 |   384.0   |
# +--------------+--------------------+--------------------+--------------------+-----------+

# %% [markdown]
# #### Simple & Classification Metrics for Model VGG19

# %%
plot_model_performance(vgg19_history, "Performance History for current VGG19 iteration")
best_vgg19_model = load_model('model_checkpoints/vgg19_brain_tumor.keras')
plot_confusion_matrix(best_vgg19_model)
# Out:
# +----+-------+----------------------+---------------------+--------------------+---------------------+--------------------+----------------------+--------------------+---------------------+
# |    | Epoch |    Training Loss     |   Validation Loss   | Training Accuracy  | Validation Accuracy | Training Precision | Validation Precision |  Training Recall   |  Validation Recall  |
# +----+-------+----------------------+---------------------+--------------------+---------------------+--------------------+----------------------+--------------------+---------------------+
# | 0  |  1.0  |  0.7697582840919495  |  1.174495816230774  | 0.6959635615348816 | 0.4635416567325592  | 0.7732217311859131 |         1.0          |     0.6015625      | 0.01822916604578495 |
# | 1  |  2.0  |  0.4285677969455719  | 1.0719223022460938  | 0.8463541865348816 | 0.5416666865348816  | 0.8760563135147095 |        0.875         | 0.8098958134651184 | 0.1458333283662796  |
# | 2  |  3.0  | 0.28285089135169983  | 0.9466180801391602  |    0.912109375     | 0.6197916865348816  | 0.9317406415939331 |  0.8705036044120789  |    0.888671875     | 0.3151041567325592  |
# | 3  |  4.0  |  0.1899252086877823  | 0.7462071776390076  |    0.935546875     | 0.7864583134651184  | 0.9465240836143494 |  0.9378238320350647  |      0.921875      | 0.4713541567325592  |
# | 4  |  5.0  | 0.13956013321876526  | 0.5819560885429382  | 0.9537760615348816 |       0.84375       | 0.9597625136375427 |  0.9202898740768433  |    0.947265625     | 0.6614583134651184  |
# | 5  |  6.0  | 0.09667367488145828  | 0.42874065041542053 | 0.9674479365348816 |      0.890625       | 0.9717662334442139 |  0.9325153231620789  | 0.9635416865348816 | 0.7916666865348816  |
# | 6  |  7.0  |  0.0893668532371521  |  0.358766108751297  | 0.9720051884651184 | 0.8802083134651184  | 0.9757058620452881 |  0.9200000166893005  | 0.9674479365348816 | 0.8385416865348816  |
# | 7  |  8.0  | 0.06960484385490417  | 0.25907304883003235 | 0.9811198115348816 | 0.9270833134651184  | 0.9810828566551208 |  0.9424657821655273  | 0.9791666865348816 | 0.8958333134651184  |
# | 8  |  9.0  | 0.056462496519088745 | 0.19576160609722137 | 0.9798176884651184 | 0.9322916865348816  | 0.9810457229614258 |  0.9342105388641357  | 0.9772135615348816 | 0.9244791865348816  |
# | 9  | 10.0  | 0.05029992759227753  | 0.1899438053369522  | 0.9837239384651184 | 0.9270833134651184  | 0.9836921095848083 |  0.9490616917610168  | 0.9817708134651184 |      0.921875       |
# | 10 | 11.0  | 0.046894121915102005 | 0.16321232914924622 | 0.9830729365348816 |       0.9375        | 0.9849672913551331 |  0.9445910453796387  | 0.9811198115348816 | 0.9322916865348816  |
# | 11 | 12.0  | 0.030548566952347755 | 0.16892369091510773 | 0.9934895634651184 | 0.9505208134651184  | 0.9934853315353394 |  0.9553805589675903  | 0.9928385615348816 | 0.9479166865348816  |
# | 12 | 13.0  | 0.03577670827507973  | 0.18645252287387848 | 0.9889323115348816 |       0.9375        | 0.9889323115348816 |  0.9518716335296631  | 0.9889323115348816 | 0.9270833134651184  |
# | 13 | 14.0  | 0.01620943285524845  | 0.15440742671489716 | 0.9973958134651184 | 0.9505208134651184  | 0.9973958134651184 |  0.9528796076774597  | 0.9973958134651184 | 0.9479166865348816  |
# | 14 | 15.0  | 0.019044937565922737 | 0.13159605860710144 | 0.9973958134651184 | 0.9557291865348816  | 0.9973941445350647 |  0.9554973840713501  | 0.9967448115348816 | 0.9505208134651184  |
# | 15 | 16.0  | 0.03230011835694313  | 0.20615999400615692 | 0.9876301884651184 | 0.9427083134651184  | 0.9876221418380737 |  0.942558765411377   | 0.9869791865348816 | 0.9401041865348816  |
# | 16 | 17.0  | 0.04376605153083801  | 0.18324029445648193 | 0.9811198115348816 |      0.953125       | 0.9811198115348816 |  0.9554973840713501  | 0.9811198115348816 | 0.9505208134651184  |
# | 17 | 18.0  | 0.02317022532224655  | 0.16013023257255554 | 0.9915364384651184 |      0.953125       | 0.9928292036056519 |  0.9580052495002747  | 0.9915364384651184 | 0.9505208134651184  |
# | 18 | 19.0  | 0.023428471758961678 | 0.2993016242980957  | 0.9934895634651184 | 0.9244791865348816  | 0.9934853315353394 |  0.9244791865348816  | 0.9928385615348816 | 0.9244791865348816  |
# | 19 | 20.0  | 0.03141901269555092  |  0.300123929977417  | 0.9908854365348816 |      0.921875       | 0.9908854365348816 |  0.9216710329055786  | 0.9908854365348816 | 0.9192708134651184  |
# | 20 | 21.0  | 0.04877164587378502  | 0.23751039803028107 | 0.9895833134651184 |      0.9453125      | 0.9902216196060181 |  0.9451696872711182  | 0.9889323115348816 | 0.9427083134651184  |
# | 21 | 22.0  | 0.017925266176462173 | 0.17743313312530518 |     0.99609375     | 0.9505208134651184  |     0.99609375     |  0.9530026316642761  |     0.99609375     | 0.9505208134651184  |
# | 22 | 23.0  | 0.011869329027831554 | 0.24320626258850098 | 0.9967448115348816 | 0.9401041865348816  | 0.9967448115348816 |  0.945026159286499   | 0.9967448115348816 | 0.9401041865348816  |
# | 23 | 24.0  | 0.020298443734645844 | 0.25365179777145386 |     0.9921875      | 0.9401041865348816  |     0.9921875      |  0.945026159286499   |     0.9921875      | 0.9401041865348816  |
# | 24 | 25.0  | 0.01760409213602543  | 0.2030235379934311  |    0.994140625     | 0.9557291865348816  | 0.9941368103027344 |  0.9557291865348816  | 0.9934895634651184 | 0.9557291865348816  |
# +----+-------+----------------------+---------------------+--------------------+---------------------+--------------------+----------------------+--------------------+---------------------+
# 12/12 [==============================] - 1s 64ms/step
# Classification Report:
# +--------------+--------------------+--------------------+--------------------+--------------------+
# |              |     precision      |       recall       |      f1-score      |      support       |
# +--------------+--------------------+--------------------+--------------------+--------------------+
# |    glioma    |        1.0         | 0.989247311827957  | 0.9945945945945946 |        93.0        |
# |  meningioma  | 0.9325842696629213 | 0.9651162790697675 | 0.9485714285714286 |        86.0        |
# |   notumor    | 0.970873786407767  | 0.8928571428571429 | 0.9302325581395349 |       112.0        |
# |  pituitary   |        0.92        | 0.989247311827957  | 0.9533678756476683 |        93.0        |
# |   accuracy   | 0.9557291666666666 | 0.9557291666666666 | 0.9557291666666666 | 0.9557291666666666 |
# |  macro avg   | 0.955864514017672  | 0.959117011395706  | 0.9566916142383066 |       384.0        |
# | weighted avg | 0.9570315397621904 | 0.9557291666666666 | 0.9555304664096386 |       384.0        |
# +--------------+--------------------+--------------------+--------------------+--------------------+
